# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahtesham-Ibne-Mostafa/Machine_Etymology/blob/main/Basic_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Traditional

# %%
c= 18

f= 1.8*c+32
f
# Out:
# 64.4

# %%
def CelToFar (c):
    f=1.8*c+32
    return f

# %%
cel_data = [34,76,35,90,12,130,68,95,100]

far_data=[]

for i in cel_data:
    far_data.append(CelToFar(i))

# %%
far_data
# Out:
# [93.2, 168.8, 95.0, 194.0, 53.6, 266.0, 154.4, 203.0, 212.0]

# %% [markdown]
# Predict cel to far

# %%
import numpy as np
import pandas as pd

# %%
data = {
        'Celsius' : cel_data,
        'Farenheit' : far_data
}

df = pd.DataFrame(data)   # dict to pandas

# %%
df
# Out:
#    Celsius  Farenheit
# 0       34       93.2
# 1       76      168.8
# 2       35       95.0
# 3       90      194.0
# 4       12       53.6
# 5      130      266.0
# 6       68      154.4
# 7       95      203.0
# 8      100      212.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1625354388690526988 = autoviz.get_registered_df('df_1625354388690526988')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1625354388690526988, *['Celsius'], **{})
# chart
# ...
